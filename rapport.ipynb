# %%
from analys import task_one, task_two, task_three, task_four, task_five, task_six

# %% [markdown]
# Uppgift 1: Beskriv data
#
# Detta är en statistisk analys som är en del av projektet i matmod kursen från hösten 2023. Datan är hämtad från https://www.smhi.se/data/meteorologi/ladda-ner-meteorologiska-observationer#param=airtemperatureInstant,stations=all. Här på länken finns csv-filer tillgängliga att ladda ner innehållande meteorlogiska observationer.
# Jag valde att hämta lufttemperatur från tre städer, Luleå, Malmö och Stockholm. Städerna är handplockade från södra, mellersta och norra Sverige där jag friserat datan att endast spegla temperaturen i Celcius mitt på dagen under julafton från år 1990-2019, närmare bestämt 30 observationer. Ett smakprov redovisas nedan i tabellen där resten går att utläsa i linjediagrammet.
# Av diagrammet kan man snabbt se att det råder lägst temperaturer uppe i Luleå. Desto varmare är det i Malmö som är tätt följt av Stockholm. Tittar man från år till år kan man även se att städerna följs ganska likt i temperaturutvecklingen, är det varmare på ett ställe är det också varmare på de två andra. Detta djupdyker jag i lite längre ner i rappporten.

# %%
task_one()
# Out:
#                      Temp-Luleå  Temp-Malmö  Temp-Stockholm
# Datum
# 1990-12-24 12:00:00         0.7         3.8             5.4
# 1991-12-24 12:00:00       -14.4         4.2            -4.3
# 1992-12-24 12:00:00         1.6        -0.1            -1.6
# 1993-12-24 12:00:00        -9.0         1.8            -1.0
# 1994-12-24 12:00:00         1.6         2.2             4.4
# 1995-12-24 12:00:00       -15.1        -8.3            -9.7
# 1996-12-24 12:00:00       -13.5        -0.5            -5.2

# %%
task_two()
# Out:
# Medelvärde:
# Temp-Luleå       -9.06
# Temp-Malmö        2.74
# Temp-Stockholm   -0.47
#
# Standardavvikelse:
# Temp-Luleå        8.33
# Temp-Malmö        3.92
# Temp-Stockholm    4.73
#
# Max temperaturer:
# Temp-Luleå        1.6
# Temp-Malmö        9.4
# Temp-Stockholm    6.7
#
# Min temperaturer:
# Temp-Luleå       -25.8
# Temp-Malmö        -8.3
# Temp-Stockholm   -10.6
#
# Korrelation mellan städerna:
#                 Temp-Luleå  Temp-Malmö  Temp-Stockholm
# Temp-Luleå            1.00        0.26            0.72
# Temp-Malmö            0.26        1.00            0.76
# Temp-Stockholm        0.72        0.76            1.00

# %% [markdown]
# Uppgift 2: Beskrivande statistik
#
# Luleå har den lägsta medeltemperaturen vilket indikerar att där genrellt sett är kallare och vise versa gällande Malmö som har högst medeltemperatur.
# Även Luleå har högst standardavvikelse som tyder på att temperaturen varierar som mest där. Mest "stabilt" är det i Malmö med sina 3.92 °C.
# Och kanske är det inte så konsigt att just Luleå uppnår den lägsta temperaturen där staden också har den lägsta maxtemperaturen, 1.6 °C respektive -25.8 °C.
# På inslagen väg toppar Malmö högst lägsta temperatur och även maxtemperaturen, inte illa med nästan 10 °C på självaste julafton!
# Korrelationen mellan städerna är intressant. Här har Stockholm både stark positiv korrelation till Malmö och Luleå vilket betyder att när temperaturen stiger eller sjunker i en stad är chansen stor att den också gör det i den andra staden. Desto lägre är den mellan Luleå och Malmö, endast 0.26. Det säger oss att dessa städer inte är lika starkt relaterade.

# %%
task_three()

# %%
task_four()
# Out:
# Koefficient a: -395.488472906404
# Koefficient b: 0.19871921182266014
# MSE: 12.098910140988618

# %%
task_five()
# Out:
# MSE för log transformerad y: 12.225557838891602
# MSE för log transformerad x: 12.102473762822767
# MSE för linjär regression: 12.098910140988618

# %%
task_six()
# Out:
# Var(R)
# Residualvarians för exponentiell modell i y: 13.131154715846536
# Residualvarians för exponentiell modell i x: 12.998953300809639
# Residualvarians för linjär regression: 12.995125706987775
#
# R^2
# R^2 för exponentiell modell i y: 0.11653025651148674
# R^2 för exponentiell modell i x: 0.12542482464040527
# R^2 för linjär regression: 0.12568234680088208

# %% [markdown]
# Uppgift 6: Residualanalys
#
# Alla modeller ser väldigt lika ut och indikerar på att residualerna följer normalfördelningen, speciellt från värdet -1.5 till 1.5.
# Residualvariansen och R^2 är mått på hur bra en modell förklarar variation i data. För originalmodellen är resultatet 12. I båda fallen är det det originalmodellen som är bäst lämpad. En lägre residualvarians och ett R^2 värde närmare 1 säger att modellen har mindre spridning mellan de verkliga och predikerade värdena vilket gör den mer tillförlitlig. Med det färskt i minnet och att plottarna inte särskiljer sig speciellt mycket från varandra landar jag i att den originalmodellen är fördelaktig för analys.

# %% [markdown]
# Uppgift 7: Sammanfattning
#
# Kort sammanfattning av analysen:
# - Sett trender i temperaturerna för våra tre städer. Starka korrelation mellan städerna bortsett från Malmö och Luleå.
# - Visualiserat ett lådagram där vi kan utläsa mycket information.
# - Skapat linjär regression för att se temperaturförändringar i Malmö. Beräknat värden för att kunna utföra en regressionsanalys.
# - Använt en logaritmisk transformation och därtill gjort både en regressions- och residualanalys som jämfördes med den ursprungliga modellen.
# - QQ-plottar för att jämföra residualerna med en normalfördelning.
#
# Slutsatser:
# - Det är kallast i norr och det blir varmare ju längre söderut vi kommer. Extremfallen hittar vi uppe i norr där det kan vända ordentligt från år till år. Skulle det visa sig vara varmare/kallare i en av städerna är chansen stor att det också är varmare/kallare i de andra städerna.
# - Regressions- och residualanalysen påvisar att originalmodellen passar bäst och att residualerna verkar följa en normalfördelning vilka påminner om varandra väldigt mycket.
# - Summa summarum kan vi med viss säkerhet förutspå temperaturförändringar i Malmö.
